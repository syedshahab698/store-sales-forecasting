# %%
import pandas as pd

# %%
# Load your sales data
sales_data = pd.read_parquet('sales.parquet.gzip')
sales_data.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
sales_data[(sales_data['date'] >= "2013-01-01") & (sales_data['date'] <= '2013-01-01') & (sales_data['family'] == "AUTOMOTIVE")]
# Out:
#         id        date  store_nbr      family  sales  onpromotion
# 0        0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 33      33  2013-01-01         10  AUTOMOTIVE    0.0            0
# 66      66  2013-01-01         11  AUTOMOTIVE    0.0            0
# 99      99  2013-01-01         12  AUTOMOTIVE    0.0            0
# 132    132  2013-01-01         13  AUTOMOTIVE    0.0            0
# 165    165  2013-01-01         14  AUTOMOTIVE    0.0            0
# 198    198  2013-01-01         15  AUTOMOTIVE    0.0            0
# 231    231  2013-01-01         16  AUTOMOTIVE    0.0            0
# 264    264  2013-01-01         17  AUTOMOTIVE    0.0            0
# 297    297  2013-01-01         18  AUTOMOTIVE    0.0            0
# 330    330  2013-01-01         19  AUTOMOTIVE    0.0            0
# 363    363  2013-01-01          2  AUTOMOTIVE    0.0            0
# 396    396  2013-01-01         20  AUTOMOTIVE    0.0            0
# ...

# %%
sales_data['date'].max()
# Out:
# '2017-08-15'
